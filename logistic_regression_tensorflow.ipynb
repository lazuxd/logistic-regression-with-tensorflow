# %% [markdown]
# # How to Implement Logistic Regression with TensorFlow
# ![alt text](imgs/lr.png)

# %%
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
x, y = df.iloc[:, 0:-1].values, df.iloc[:, -1].values.reshape((-1, 1))
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8)

# %%
scaler = MinMaxScaler().fit(x_train)
x_train, x_test = scaler.transform(x_train), scaler.transform(x_test)

# %% [markdown]
# ## TL; DR
# If you are here for a quick solution that just works, then here it is in just 5 lines of code:

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='bce', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=500)
# Out:
# Epoch 1/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.7134 - accuracy: 0.4545
# Epoch 2/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.7084 - accuracy: 0.4752
# Epoch 3/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7047 - accuracy: 0.4793
# Epoch 4/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.7016 - accuracy: 0.4752
# Epoch 5/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.6985 - accuracy: 0.4959
# Epoch 6/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6958 - accuracy: 0.5000
# Epoch 7/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6930 - accuracy: 0.5041
# Epoch 8/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6903 - accuracy: 0.5083
# Epoch 9/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6875 - accuracy: 0.5207
# Epoch 10/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6848 - accuracy: 0.5248
# Epoch 11/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.6821 - accuracy: 0.5248
# Epoch 12/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6794 - accuracy: 0.5372
# Epoch 13/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6768 - accuracy: 0.5496
# Epoch 14/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6741 - accuracy: 0.5579
# Epoch 15/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6718 - accuracy: 0.5744
# Epoch 16/500
# 8/8 [==============================] - ETA: 0s - loss: 0.6730 - accuracy: 0.56 - 0s 998us/step - loss: 0.6690 - accuracy: 0.5909
# Epoch 17/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6664 - accuracy: 0.6240
# Epoch 18/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6638 - accuracy: 0.6281
# Epoch 19/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6612 - accuracy: 0.6364
# Epoch 20/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6588 - accuracy: 0.6364
# Epoch 21/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6565 - accuracy: 0.6405
# Epoch 22/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6541 - accuracy: 0.6405
# Epoch 23/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6517 - accuracy: 0.6488
# Epoch 24/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6494 - accuracy: 0.6570
# Epoch 25/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.6472 - accuracy: 0.6570
# Epoch 26/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6448 - accuracy: 0.6612
# Epoch 27/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6425 - accuracy: 0.6736
# Epoch 28/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6403 - accuracy: 0.6818
# Epoch 29/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6380 - accuracy: 0.6818
# Epoch 30/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.6357 - accuracy: 0.6818
# Epoch 31/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6335 - accuracy: 0.6901
# Epoch 32/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6314 - accuracy: 0.6942
# Epoch 33/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6290 - accuracy: 0.6942
# Epoch 34/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6271 - accuracy: 0.6983
# Epoch 35/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6249 - accuracy: 0.7025
# Epoch 36/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6227 - accuracy: 0.7025
# Epoch 37/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6207 - accuracy: 0.7066
# Epoch 38/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.6188 - accuracy: 0.7107
# Epoch 39/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6166 - accuracy: 0.7107
# Epoch 40/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6147 - accuracy: 0.7107
# Epoch 41/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6127 - accuracy: 0.7190
# Epoch 42/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6105 - accuracy: 0.7149
# Epoch 43/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6088 - accuracy: 0.7231
# Epoch 44/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6067 - accuracy: 0.7273
# Epoch 45/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6048 - accuracy: 0.7273
# Epoch 46/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.6029 - accuracy: 0.7314
# Epoch 47/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6008 - accuracy: 0.7273
# Epoch 48/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5990 - accuracy: 0.7273
# Epoch 49/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5971 - accuracy: 0.7273
# Epoch 50/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5952 - accuracy: 0.7273
# Epoch 51/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5934 - accuracy: 0.7355
# Epoch 52/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5917 - accuracy: 0.7314
# Epoch 53/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5898 - accuracy: 0.7314
# Epoch 54/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5880 - accuracy: 0.7397
# Epoch 55/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5862 - accuracy: 0.7438
# Epoch 56/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5847 - accuracy: 0.7438
# Epoch 57/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5830 - accuracy: 0.7438
# Epoch 58/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5813 - accuracy: 0.7438
# Epoch 59/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5797 - accuracy: 0.7438
# Epoch 60/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.5780 - accuracy: 0.7438
# Epoch 61/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5763 - accuracy: 0.7438
# Epoch 62/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5747 - accuracy: 0.7479
# Epoch 63/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5732 - accuracy: 0.7479
# Epoch 64/500
# 8/8 [==============================] - 0s 874us/step - loss: 0.5716 - accuracy: 0.7438
# Epoch 65/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5703 - accuracy: 0.7438
# Epoch 66/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5686 - accuracy: 0.7479
# Epoch 67/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5670 - accuracy: 0.7479
# Epoch 68/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5653 - accuracy: 0.7521
# Epoch 69/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5637 - accuracy: 0.7479
# Epoch 70/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.5621 - accuracy: 0.7479
# Epoch 71/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5605 - accuracy: 0.7479
# Epoch 72/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5589 - accuracy: 0.7479
# Epoch 73/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5575 - accuracy: 0.7479
# Epoch 74/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5561 - accuracy: 0.7562
# Epoch 75/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5547 - accuracy: 0.7521
# Epoch 76/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5532 - accuracy: 0.7603
# Epoch 77/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5519 - accuracy: 0.7603
# Epoch 78/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.5505 - accuracy: 0.7562
# Epoch 79/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5492 - accuracy: 0.7562
# Epoch 80/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5478 - accuracy: 0.7603
# Epoch 81/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5466 - accuracy: 0.7562
# Epoch 82/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5452 - accuracy: 0.7603
# Epoch 83/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5439 - accuracy: 0.7686
# Epoch 84/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5426 - accuracy: 0.7645
# Epoch 85/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5412 - accuracy: 0.7727
# Epoch 86/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.5401 - accuracy: 0.7686
# Epoch 87/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5388 - accuracy: 0.7686
# Epoch 88/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5378 - accuracy: 0.7686
# Epoch 89/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5367 - accuracy: 0.7686
# Epoch 90/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5354 - accuracy: 0.7686
# Epoch 91/500
# 8/8 [==============================] - 0s 749us/step - loss: 0.5343 - accuracy: 0.7727
# Epoch 92/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5331 - accuracy: 0.7686
# Epoch 93/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5319 - accuracy: 0.7686
# Epoch 94/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5308 - accuracy: 0.7727
# Epoch 95/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5296 - accuracy: 0.7727
# Epoch 96/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5286 - accuracy: 0.7727
# Epoch 97/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.5273 - accuracy: 0.7727
# Epoch 98/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.5262 - accuracy: 0.7769
# Epoch 99/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5253 - accuracy: 0.7769
# Epoch 100/500
# 8/8 [==============================] - 0s 748us/step - loss: 0.5241 - accuracy: 0.7769
# Epoch 101/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5230 - accuracy: 0.7769
# Epoch 102/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5219 - accuracy: 0.7769
# Epoch 103/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5209 - accuracy: 0.7727
# Epoch 104/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5198 - accuracy: 0.7769
# Epoch 105/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5188 - accuracy: 0.7769
# Epoch 106/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5177 - accuracy: 0.7810
# Epoch 107/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5168 - accuracy: 0.7769
# Epoch 108/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5156 - accuracy: 0.7810
# Epoch 109/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5149 - accuracy: 0.7851
# Epoch 110/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5136 - accuracy: 0.7851
# Epoch 111/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5128 - accuracy: 0.7810
# Epoch 112/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5118 - accuracy: 0.7851
# Epoch 113/500
# 8/8 [==============================] - 0s 876us/step - loss: 0.5107 - accuracy: 0.7851
# Epoch 114/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5098 - accuracy: 0.7851
# Epoch 115/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5090 - accuracy: 0.7851
# Epoch 116/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5079 - accuracy: 0.7851
# Epoch 117/500
# 8/8 [==============================] - 0s 874us/step - loss: 0.5071 - accuracy: 0.7851
# Epoch 118/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.5061 - accuracy: 0.7851
# Epoch 119/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.5051 - accuracy: 0.7851
# Epoch 120/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.5042 - accuracy: 0.7851
# Epoch 121/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5033 - accuracy: 0.7851
# Epoch 122/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.5026 - accuracy: 0.7851
# Epoch 123/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.5015 - accuracy: 0.7851
# Epoch 124/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.5007 - accuracy: 0.7851
# Epoch 125/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4999 - accuracy: 0.7851
# Epoch 126/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4990 - accuracy: 0.7851
# Epoch 127/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4983 - accuracy: 0.7810
# Epoch 128/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4974 - accuracy: 0.7851
# Epoch 129/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4967 - accuracy: 0.7810
# Epoch 130/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4961 - accuracy: 0.7810
# Epoch 131/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4953 - accuracy: 0.7810
# Epoch 132/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4944 - accuracy: 0.7810
# Epoch 133/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4936 - accuracy: 0.7810
# Epoch 134/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4928 - accuracy: 0.7810
# Epoch 135/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4920 - accuracy: 0.7810
# Epoch 136/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4914 - accuracy: 0.7851
# Epoch 137/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4905 - accuracy: 0.7810
# Epoch 138/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.4898 - accuracy: 0.7851
# Epoch 139/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4891 - accuracy: 0.7851
# Epoch 140/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.4884 - accuracy: 0.7851
# Epoch 141/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4878 - accuracy: 0.7851
# Epoch 142/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4871 - accuracy: 0.7851
# Epoch 143/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4864 - accuracy: 0.7851
# Epoch 144/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4857 - accuracy: 0.7851
# Epoch 145/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4850 - accuracy: 0.7851
# Epoch 146/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4842 - accuracy: 0.7851
# Epoch 147/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4836 - accuracy: 0.7851
# Epoch 148/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4829 - accuracy: 0.7851
# Epoch 149/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4823 - accuracy: 0.7851
# Epoch 150/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4816 - accuracy: 0.7851
# Epoch 151/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4810 - accuracy: 0.7851
# Epoch 152/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4804 - accuracy: 0.7851
# Epoch 153/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4798 - accuracy: 0.7851
# Epoch 154/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4792 - accuracy: 0.7851
# Epoch 155/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4785 - accuracy: 0.7851
# Epoch 156/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4779 - accuracy: 0.7851
# Epoch 157/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4774 - accuracy: 0.7851
# Epoch 158/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4767 - accuracy: 0.7851
# Epoch 159/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4759 - accuracy: 0.7851
# Epoch 160/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4754 - accuracy: 0.7851
# Epoch 161/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4747 - accuracy: 0.7851
# Epoch 162/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4741 - accuracy: 0.7851
# Epoch 163/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4736 - accuracy: 0.7851
# Epoch 164/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4730 - accuracy: 0.7851
# Epoch 165/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4724 - accuracy: 0.7851
# Epoch 166/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.4721 - accuracy: 0.7851
# Epoch 167/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4715 - accuracy: 0.7851
# Epoch 168/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4709 - accuracy: 0.7851
# Epoch 169/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4705 - accuracy: 0.7851
# Epoch 170/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4699 - accuracy: 0.7851
# Epoch 171/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4693 - accuracy: 0.7851
# Epoch 172/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4688 - accuracy: 0.7851
# Epoch 173/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4682 - accuracy: 0.7851
# Epoch 174/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4676 - accuracy: 0.7851
# Epoch 175/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4671 - accuracy: 0.7893
# Epoch 176/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4664 - accuracy: 0.7893
# Epoch 177/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4660 - accuracy: 0.7893
# Epoch 178/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4654 - accuracy: 0.7975
# Epoch 179/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4649 - accuracy: 0.7934
# Epoch 180/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4644 - accuracy: 0.7975
# Epoch 181/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4639 - accuracy: 0.7934
# Epoch 182/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4634 - accuracy: 0.7934
# Epoch 183/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4630 - accuracy: 0.7975
# Epoch 184/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4626 - accuracy: 0.7975
# Epoch 185/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4620 - accuracy: 0.7975
# Epoch 186/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4616 - accuracy: 0.7934
# Epoch 187/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4611 - accuracy: 0.7934
# Epoch 188/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4605 - accuracy: 0.7934
# Epoch 189/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4601 - accuracy: 0.7934
# Epoch 190/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4596 - accuracy: 0.7934
# Epoch 191/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4592 - accuracy: 0.7934
# Epoch 192/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4587 - accuracy: 0.7934
# Epoch 193/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4583 - accuracy: 0.7934
# Epoch 194/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4578 - accuracy: 0.7934
# Epoch 195/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4573 - accuracy: 0.7934
# Epoch 196/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4572 - accuracy: 0.7934
# Epoch 197/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4567 - accuracy: 0.7934
# Epoch 198/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4563 - accuracy: 0.7934
# Epoch 199/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4558 - accuracy: 0.7934
# Epoch 200/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4554 - accuracy: 0.7934
# Epoch 201/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4549 - accuracy: 0.7934
# Epoch 202/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4545 - accuracy: 0.7934
# Epoch 203/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4541 - accuracy: 0.7975
# Epoch 204/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4536 - accuracy: 0.7975
# Epoch 205/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4533 - accuracy: 0.7934
# Epoch 206/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4527 - accuracy: 0.7975
# Epoch 207/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4524 - accuracy: 0.7975
# Epoch 208/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4519 - accuracy: 0.7975
# Epoch 209/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4515 - accuracy: 0.7975
# Epoch 210/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4511 - accuracy: 0.8017
# Epoch 211/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4508 - accuracy: 0.8017
# Epoch 212/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4503 - accuracy: 0.7975
# Epoch 213/500
# 8/8 [==============================] - 0s 874us/step - loss: 0.4498 - accuracy: 0.8017
# Epoch 214/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4496 - accuracy: 0.8017
# Epoch 215/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4492 - accuracy: 0.8017
# Epoch 216/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4487 - accuracy: 0.8017
# Epoch 217/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4486 - accuracy: 0.8017
# Epoch 218/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4481 - accuracy: 0.8017
# Epoch 219/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4477 - accuracy: 0.8017
# Epoch 220/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4473 - accuracy: 0.8017
# Epoch 221/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4469 - accuracy: 0.8058
# Epoch 222/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4466 - accuracy: 0.8017
# Epoch 223/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4464 - accuracy: 0.8017
# Epoch 224/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4458 - accuracy: 0.8058
# Epoch 225/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4458 - accuracy: 0.8058
# Epoch 226/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4453 - accuracy: 0.8017
# Epoch 227/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4449 - accuracy: 0.8099
# Epoch 228/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4446 - accuracy: 0.8058
# Epoch 229/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4444 - accuracy: 0.8058
# Epoch 230/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4443 - accuracy: 0.8017
# Epoch 231/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4439 - accuracy: 0.8058
# Epoch 232/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4434 - accuracy: 0.8058
# Epoch 233/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4432 - accuracy: 0.8058
# Epoch 234/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4429 - accuracy: 0.8058
# Epoch 235/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4425 - accuracy: 0.8058
# Epoch 236/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4423 - accuracy: 0.8058
# Epoch 237/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4419 - accuracy: 0.8058
# Epoch 238/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4416 - accuracy: 0.8058
# Epoch 239/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4412 - accuracy: 0.8140
# Epoch 240/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4410 - accuracy: 0.8140
# Epoch 241/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4406 - accuracy: 0.8140
# Epoch 242/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4403 - accuracy: 0.8140
# Epoch 243/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.4400 - accuracy: 0.8140
# Epoch 244/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4397 - accuracy: 0.8140
# Epoch 245/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4395 - accuracy: 0.8140
# Epoch 246/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4392 - accuracy: 0.8140
# Epoch 247/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4389 - accuracy: 0.8140
# Epoch 248/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4386 - accuracy: 0.8140
# Epoch 249/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4383 - accuracy: 0.8140
# Epoch 250/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4379 - accuracy: 0.8140
# Epoch 251/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4378 - accuracy: 0.8140
# Epoch 252/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4375 - accuracy: 0.8140
# Epoch 253/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4371 - accuracy: 0.8140
# Epoch 254/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4369 - accuracy: 0.8140
# Epoch 255/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4366 - accuracy: 0.8140
# Epoch 256/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4364 - accuracy: 0.8140
# Epoch 257/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4360 - accuracy: 0.8140
# Epoch 258/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4358 - accuracy: 0.8140
# Epoch 259/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4354 - accuracy: 0.8140
# Epoch 260/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4355 - accuracy: 0.8140
# Epoch 261/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4350 - accuracy: 0.8140
# Epoch 262/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4349 - accuracy: 0.8140
# Epoch 263/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4347 - accuracy: 0.8140
# Epoch 264/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4344 - accuracy: 0.8140
# Epoch 265/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4341 - accuracy: 0.8140
# Epoch 266/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4339 - accuracy: 0.8140
# Epoch 267/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4336 - accuracy: 0.8099
# Epoch 268/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4334 - accuracy: 0.8099
# Epoch 269/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4331 - accuracy: 0.8099
# Epoch 270/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4329 - accuracy: 0.8099
# Epoch 271/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4328 - accuracy: 0.8140
# Epoch 272/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4324 - accuracy: 0.8099
# Epoch 273/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4321 - accuracy: 0.8099
# Epoch 274/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4320 - accuracy: 0.8099
# Epoch 275/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4316 - accuracy: 0.8099
# Epoch 276/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4315 - accuracy: 0.8099
# Epoch 277/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4312 - accuracy: 0.8099
# Epoch 278/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4310 - accuracy: 0.8099
# Epoch 279/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4307 - accuracy: 0.8099
# Epoch 280/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4304 - accuracy: 0.8099
# Epoch 281/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4302 - accuracy: 0.8099
# Epoch 282/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4298 - accuracy: 0.8099
# Epoch 283/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4299 - accuracy: 0.8099
# Epoch 284/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.4295 - accuracy: 0.8099
# Epoch 285/500
# 8/8 [==============================] - 0s 874us/step - loss: 0.4293 - accuracy: 0.8058
# Epoch 286/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4290 - accuracy: 0.8099
# Epoch 287/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4288 - accuracy: 0.8058
# Epoch 288/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4285 - accuracy: 0.8099
# Epoch 289/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4284 - accuracy: 0.8058
# Epoch 290/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4282 - accuracy: 0.8058
# Epoch 291/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4279 - accuracy: 0.8058
# Epoch 292/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4277 - accuracy: 0.8058
# Epoch 293/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4275 - accuracy: 0.8058
# Epoch 294/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4274 - accuracy: 0.8058
# Epoch 295/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4271 - accuracy: 0.8058
# Epoch 296/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4268 - accuracy: 0.8058
# Epoch 297/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4268 - accuracy: 0.8058
# Epoch 298/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4265 - accuracy: 0.8058
# Epoch 299/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4263 - accuracy: 0.8058
# Epoch 300/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4261 - accuracy: 0.8058
# Epoch 301/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4259 - accuracy: 0.8058
# Epoch 302/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4257 - accuracy: 0.8058
# Epoch 303/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4255 - accuracy: 0.8058
# Epoch 304/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4253 - accuracy: 0.8058
# Epoch 305/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4250 - accuracy: 0.8058
# Epoch 306/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4249 - accuracy: 0.8058
# Epoch 307/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4248 - accuracy: 0.8058
# Epoch 308/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4245 - accuracy: 0.8058
# Epoch 309/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4243 - accuracy: 0.8058
# Epoch 310/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4241 - accuracy: 0.8058
# Epoch 311/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4239 - accuracy: 0.8058
# Epoch 312/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4237 - accuracy: 0.8058
# Epoch 313/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4236 - accuracy: 0.8058
# Epoch 314/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4234 - accuracy: 0.8058
# Epoch 315/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4232 - accuracy: 0.8058
# Epoch 316/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4231 - accuracy: 0.8099
# Epoch 317/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4228 - accuracy: 0.8099
# Epoch 318/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4228 - accuracy: 0.8099
# Epoch 319/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4224 - accuracy: 0.8058
# Epoch 320/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4223 - accuracy: 0.8099
# Epoch 321/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4222 - accuracy: 0.8058
# Epoch 322/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4219 - accuracy: 0.8099
# Epoch 323/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4218 - accuracy: 0.8058
# Epoch 324/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4216 - accuracy: 0.8058
# Epoch 325/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4214 - accuracy: 0.8099
# Epoch 326/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4215 - accuracy: 0.8099
# Epoch 327/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4211 - accuracy: 0.8099
# Epoch 328/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4210 - accuracy: 0.8140
# Epoch 329/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4208 - accuracy: 0.8099
# Epoch 330/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4207 - accuracy: 0.8099
# Epoch 331/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4206 - accuracy: 0.8140
# Epoch 332/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4203 - accuracy: 0.8140
# Epoch 333/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4202 - accuracy: 0.8140
# Epoch 334/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4201 - accuracy: 0.8140
# Epoch 335/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4198 - accuracy: 0.8140
# Epoch 336/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4197 - accuracy: 0.8140
# Epoch 337/500
# 8/8 [==============================] - 0s 998us/step - loss: 0.4197 - accuracy: 0.8140
# Epoch 338/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4196 - accuracy: 0.8140
# Epoch 339/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4193 - accuracy: 0.8140
# Epoch 340/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4192 - accuracy: 0.8140
# Epoch 341/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4190 - accuracy: 0.8140
# Epoch 342/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4190 - accuracy: 0.8140
# Epoch 343/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4187 - accuracy: 0.8140
# Epoch 344/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4185 - accuracy: 0.8140
# Epoch 345/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4184 - accuracy: 0.8140
# Epoch 346/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4182 - accuracy: 0.8140
# Epoch 347/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4182 - accuracy: 0.8140
# Epoch 348/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4181 - accuracy: 0.8140
# Epoch 349/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4180 - accuracy: 0.8140
# Epoch 350/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4176 - accuracy: 0.8140
# Epoch 351/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.4175 - accuracy: 0.8140
# Epoch 352/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4174 - accuracy: 0.8140
# Epoch 353/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4173 - accuracy: 0.8099
# Epoch 354/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4171 - accuracy: 0.8140
# Epoch 355/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4170 - accuracy: 0.8140
# Epoch 356/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4168 - accuracy: 0.8140
# Epoch 357/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4167 - accuracy: 0.8099
# Epoch 358/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4164 - accuracy: 0.8099
# Epoch 359/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4164 - accuracy: 0.8099
# Epoch 360/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4162 - accuracy: 0.8099
# Epoch 361/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4159 - accuracy: 0.8099
# Epoch 362/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4160 - accuracy: 0.8140
# Epoch 363/500
# 8/8 [==============================] - 0s 749us/step - loss: 0.4158 - accuracy: 0.8099
# Epoch 364/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4156 - accuracy: 0.8099
# Epoch 365/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4155 - accuracy: 0.8099
# Epoch 366/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4154 - accuracy: 0.8099
# Epoch 367/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4152 - accuracy: 0.8099
# Epoch 368/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4152 - accuracy: 0.8140
# Epoch 369/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4149 - accuracy: 0.8099
# Epoch 370/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4148 - accuracy: 0.8099
# Epoch 371/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4147 - accuracy: 0.8099
# Epoch 372/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4146 - accuracy: 0.8099
# Epoch 373/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4145 - accuracy: 0.8099
# Epoch 374/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4143 - accuracy: 0.8099
# Epoch 375/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4141 - accuracy: 0.8140
# Epoch 376/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4140 - accuracy: 0.8099
# Epoch 377/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4140 - accuracy: 0.8140
# Epoch 378/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4137 - accuracy: 0.8140
# Epoch 379/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4137 - accuracy: 0.8099
# Epoch 380/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4137 - accuracy: 0.8140
# Epoch 381/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4135 - accuracy: 0.8140
# Epoch 382/500
# 8/8 [==============================] - 0s 876us/step - loss: 0.4133 - accuracy: 0.8140
# Epoch 383/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4132 - accuracy: 0.8223
# Epoch 384/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4131 - accuracy: 0.8140
# Epoch 385/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4131 - accuracy: 0.8182
# Epoch 386/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4128 - accuracy: 0.8140
# Epoch 387/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4129 - accuracy: 0.8140
# Epoch 388/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4127 - accuracy: 0.8140
# Epoch 389/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4126 - accuracy: 0.8140
# Epoch 390/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4126 - accuracy: 0.8182
# Epoch 391/500
# 8/8 [==============================] - 0s 874us/step - loss: 0.4124 - accuracy: 0.8140
# Epoch 392/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4123 - accuracy: 0.8223
# Epoch 393/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4124 - accuracy: 0.8140
# Epoch 394/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4121 - accuracy: 0.8140
# Epoch 395/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4119 - accuracy: 0.8140
# Epoch 396/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4120 - accuracy: 0.8140
# Epoch 397/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4117 - accuracy: 0.8140
# Epoch 398/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4116 - accuracy: 0.8140
# Epoch 399/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4116 - accuracy: 0.8140
# Epoch 400/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4114 - accuracy: 0.8140
# Epoch 401/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4113 - accuracy: 0.8182
# Epoch 402/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4112 - accuracy: 0.8182
# Epoch 403/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4110 - accuracy: 0.8223
# Epoch 404/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4112 - accuracy: 0.8182
# Epoch 405/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.4108 - accuracy: 0.8182
# Epoch 406/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4109 - accuracy: 0.8223
# Epoch 407/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4107 - accuracy: 0.8223
# Epoch 408/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.4106 - accuracy: 0.8182
# Epoch 409/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4104 - accuracy: 0.8223
# Epoch 410/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4104 - accuracy: 0.8223
# Epoch 411/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4103 - accuracy: 0.8223
# Epoch 412/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4102 - accuracy: 0.8264
# Epoch 413/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4102 - accuracy: 0.8223
# Epoch 414/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4100 - accuracy: 0.8223
# Epoch 415/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4099 - accuracy: 0.8223
# Epoch 416/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4098 - accuracy: 0.8182
# Epoch 417/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4098 - accuracy: 0.8182
# Epoch 418/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4097 - accuracy: 0.8223
# Epoch 419/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4098 - accuracy: 0.8182
# Epoch 420/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4096 - accuracy: 0.8182
# Epoch 421/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4094 - accuracy: 0.8182
# Epoch 422/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4093 - accuracy: 0.8182
# Epoch 423/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4093 - accuracy: 0.8306
# Epoch 424/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4092 - accuracy: 0.8223
# Epoch 425/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4091 - accuracy: 0.8306
# Epoch 426/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4089 - accuracy: 0.8223
# Epoch 427/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4090 - accuracy: 0.8264
# Epoch 428/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4088 - accuracy: 0.8264
# Epoch 429/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4087 - accuracy: 0.8223
# Epoch 430/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4088 - accuracy: 0.8264
# Epoch 431/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4085 - accuracy: 0.8306
# Epoch 432/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4085 - accuracy: 0.8264
# Epoch 433/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4084 - accuracy: 0.8306
# Epoch 434/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.4083 - accuracy: 0.8264
# Epoch 435/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4083 - accuracy: 0.8306
# Epoch 436/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4082 - accuracy: 0.8347
# Epoch 437/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4080 - accuracy: 0.8306
# Epoch 438/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4080 - accuracy: 0.8306
# Epoch 439/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4079 - accuracy: 0.8306
# Epoch 440/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4079 - accuracy: 0.8306
# Epoch 441/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4078 - accuracy: 0.8306
# Epoch 442/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4078 - accuracy: 0.8306
# Epoch 443/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4075 - accuracy: 0.8306
# Epoch 444/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4075 - accuracy: 0.8306
# Epoch 445/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4075 - accuracy: 0.8306
# Epoch 446/500
# 8/8 [==============================] - 0s 874us/step - loss: 0.4074 - accuracy: 0.8306
# Epoch 447/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4073 - accuracy: 0.8306
# Epoch 448/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4073 - accuracy: 0.8306
# Epoch 449/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4070 - accuracy: 0.8306
# Epoch 450/500
# 8/8 [==============================] - 0s 2ms/step - loss: 0.4069 - accuracy: 0.8306
# Epoch 451/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4069 - accuracy: 0.8306
# Epoch 452/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4069 - accuracy: 0.8306
# Epoch 453/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4069 - accuracy: 0.8306
# Epoch 454/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4066 - accuracy: 0.8306
# Epoch 455/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4066 - accuracy: 0.8306
# Epoch 456/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4065 - accuracy: 0.8306
# Epoch 457/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4064 - accuracy: 0.8306
# Epoch 458/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4063 - accuracy: 0.8306
# Epoch 459/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4063 - accuracy: 0.8306
# Epoch 460/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4062 - accuracy: 0.8306
# Epoch 461/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4061 - accuracy: 0.8306
# Epoch 462/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4060 - accuracy: 0.8306
# Epoch 463/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4059 - accuracy: 0.8306
# Epoch 464/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4059 - accuracy: 0.8306
# Epoch 465/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4057 - accuracy: 0.8306
# Epoch 466/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4057 - accuracy: 0.8306
# Epoch 467/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4057 - accuracy: 0.8306
# Epoch 468/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4056 - accuracy: 0.8306
# Epoch 469/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4054 - accuracy: 0.8306
# Epoch 470/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4055 - accuracy: 0.8306
# Epoch 471/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4053 - accuracy: 0.8306
# Epoch 472/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4053 - accuracy: 0.8306
# Epoch 473/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4052 - accuracy: 0.8306
# Epoch 474/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4050 - accuracy: 0.8264
# Epoch 475/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4050 - accuracy: 0.8264
# Epoch 476/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4052 - accuracy: 0.8264
# Epoch 477/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4048 - accuracy: 0.8306
# Epoch 478/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4050 - accuracy: 0.8306
# Epoch 479/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4048 - accuracy: 0.8306
# Epoch 480/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4046 - accuracy: 0.8264
# Epoch 481/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4047 - accuracy: 0.8306
# Epoch 482/500
# 8/8 [==============================] - ETA: 0s - loss: 0.3598 - accuracy: 0.93 - 0s 1000us/step - loss: 0.4045 - accuracy: 0.8223
# Epoch 483/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4046 - accuracy: 0.8264
# Epoch 484/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4044 - accuracy: 0.8264
# Epoch 485/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4043 - accuracy: 0.8264
# Epoch 486/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4044 - accuracy: 0.8264
# Epoch 487/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4042 - accuracy: 0.8264
# Epoch 488/500
# 8/8 [==============================] - 0s 749us/step - loss: 0.4041 - accuracy: 0.8223
# Epoch 489/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4040 - accuracy: 0.8223
# Epoch 490/500
# 8/8 [==============================] - 0s 1000us/step - loss: 0.4041 - accuracy: 0.8223
# Epoch 491/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4040 - accuracy: 0.8223
# Epoch 492/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4039 - accuracy: 0.8223
# Epoch 493/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4040 - accuracy: 0.8223
# Epoch 494/500
# 8/8 [==============================] - 0s 874us/step - loss: 0.4037 - accuracy: 0.8223
# Epoch 495/500
# 8/8 [==============================] - 0s 1ms/step - loss: 0.4037 - accuracy: 0.8223
# Epoch 496/500
# 8/8 [==============================] - 0s 750us/step - loss: 0.4036 - accuracy: 0.8223
# Epoch 497/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4037 - accuracy: 0.8223
# Epoch 498/500
# 8/8 [==============================] - 0s 999us/step - loss: 0.4037 - accuracy: 0.8223
# Epoch 499/500
# 8/8 [==============================] - 0s 877us/step - loss: 0.4034 - accuracy: 0.8223
# Epoch 500/500
# 8/8 [==============================] - 0s 875us/step - loss: 0.4035 - accuracy: 0.8223

# %% [markdown]
# Now, let's evaluate our model:

# %%
model.evaluate(x_test, y_test)
# Out:
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2835 - accuracy: 0.8689
# [0.28348901867866516, 0.868852436542511]

# %% [markdown]
# ## The long way
# Now, if you’re still with me it means that you don’t want just to copy + paste 5 lines of code, but to see how you can actually implement this method yourself from scratch.
# TensorFlow is a rich library; it has many APIs that you can use. Among them is the Keras API which can be used to build a logistic regression model very quickly, as you can see above. And there’s nothing wrong with that. If you have to implement a complex deep learning model, that perhaps you saw in a new paper, Keras saves you a lot of time; it lets you focus on what’s important and don’t have to care about each math operation that has to be done.
# But, if your purpose is to learn a basic machine learning technique, like logistic regression, it is worth it using the core math functions from TensorFlow and implementing it from scratch.
# Knowing TensorFlow’s lower-level math APIs also can help you building a deep learning model when you need to implement a custom training loop, or a custom activation or loss function. It can also be more fun!
# So, let’s get started!

# %% [markdown]
# To understand better what we’re going to do next, you can read [this article about logistic regression](https://towardsdatascience.com/understanding-logistic-regression-81779525d5c6).
# What's our plan for implementing Logistic Regression with TensorFlow?
# Let's first think of the underlying math that we want to use.
# There are many ways to define a loss function and then find the optimal parameters for it, among them, here we will implement in our `LogisticRegression` class the following 3 ways for learning the parameters:
# - We will rewrite the logistic regression equation so that we turn it into a least-squares linear regression problem with different labels and then, we use the closed-form formula to find the weights: ![at text](imgs/eq1.png)
# - Like above, we turn logistic into least-squares linear regression, but instead of the closed-form formula, we use stochastic gradient descent (SGD) to minimize the following loss function: ![alt text](imgs/eq4.png) which was obtained by substituting the y in the sum of squared errors loss ![alt text](imgs/eq3.png) with the right-hand side of ![alt text](imgs/eq2.png)
# - We use the maximum likelihood estimation (MLE) method, write the likelihood function, play around with it, restate it as a minimization problem, and apply SGD with the following loss function: ![alt text](imgs/eq5.png)

# %% [markdown]
# In the above equations, X is the input matrix that contains observations on the row axis and features on the column axis; y is a column vector that contains the classification labels (0 or 1); f is the sum of squared errors loss function; h is the loss function for the MLE method.
# If you want to find out more about how we obtained the above equations, please check out the above-linked article.
# So now, this is our goal: translate the above equations into code. And we’ll use TensorFlow for that.
# We plan to use an object-oriented approach for implementation. We'll create a `LogisticRegression` class with 3 public methods: `fit()`, `predict()`, and `accuracy()`.
# Among fit's parameters, one will determine how our model learns. This parameter is named method (not to be confused with a method as a function of a class) and it can take the following strings as values: 'ols_solve' (OLS stands for Ordinary Least Squares), 'ols_sgd’, and 'mle_sgd’.
# To not make the `fit()` method too long, we would like to split the code into 3 different private methods, each one responsible for one way of finding the parameters.
# We will have the `__ols_solve()` private method for applying the closed-form formula.
# In this method and in the other methods that use the OLS approach, we will use the constant EPS to make sure the labels are not exactly 0 or 1, but something in between. That’s to avoid getting plus or minus infinity for the logarithm in the equations above.
# In `__ols_solve()` we first check if X has full column rank so that we can apply this method. Then we force y to be between EPS and 1-EPS. The `ols_y` variable holds the labels of the ordinary least-squares linear regression problem that’s equivalent to our logistic regression problem. Basically, we transform the labels that we have for logistic regression so that they are compliant with the linear regression equations. After that, we apply the closed-form formula using TensorFlow functions.

# %% [markdown]
# ```python
# EPS = 1e-5
# def __ols_solve(self, x, y):
#     rows, cols = x.shape
#     if rows >= cols == tf.linalg.matrix_rank(x):
#         y = tf.math.maximum(self.EPS,
#                             tf.math.minimum(tf.cast(y, tf.float32), 1-self.EPS))
#         ols_y = -tf.math.log(tf.math.divide(1, y) - 1)
#         self.weights = tf.linalg.matmul(
#             tf.linalg.matmul(
#                 tf.linalg.inv(
#                     tf.linalg.matmul(x, x, transpose_a=True)
#                 ),
#                 x, transpose_b=True),
#             ols_y)
#     else:
#         print('Error! X has not full column rank.')
# ```

# %% [markdown]
# For the 2 SGD-based algorithms, it would be redundant to have them as 2 separate methods since they will have almost all the code the same except for the part where we compute the loss value, as we have 2 different loss functions for them.
# What we’ll do is to create a generic `__sgd()` method that does not rely on a particular loss function. Instead, it will expect as a parameter a function responsible for computing the loss value which the `__sgd()` method will use.
# In this method, we first initialize the weights to a random column vector with values drawn from a normal distribution with mean 0 and a standard deviation of 1/(# of features). The intuition for this std dev is that if we have more features, then we need smaller weights to be able to converge (and not blow up our gradients). Then we go through all the dataset for `iterations` times. At the start of each such iteration, we randomly shuffle our dataset, then for each batch of data, we compute the loss value using the `loss_fn` function taken as a parameter, then use TensorFlow to take the gradient of this loss value with respect to (w.r.t.) `self.weights` and update the weights.
# The loss needs to be computed inside `with tf.GradientTape() as tape:` block. This is to tell TensorFlow to keep track of the operations applied so that it knows how to take the gradient.
# Then, to take the gradient of the loss w.r.t. weights we use `grads = tape.gradient(loss, self.weights)`, and to subtract the gradient multiplied with the learning rate we use `self.weights.assign_sub(learning_rate*grads)`.

# %% [markdown]
# ```python
# def __sgd(self, x, y, loss_fn, learning_rate, iterations, batch_size):
#     rows, cols = x.shape
#     self.weights = tf.Variable(tf.random.normal(stddev=1.0/cols, shape=(cols, 1)))
#     dataset = tf.data.Dataset.from_tensor_slices((x, y)).batch(batch_size)
#
#     for i in range(iterations):
#         dataset.shuffle(buffer_size=1024)
#         for step, (xb, yb) in enumerate(dataset):
#             with tf.GradientTape() as tape:
#                 loss = loss_fn(xb, yb)
#             grads = tape.gradient(loss, self.weights)
#             self.weights.assign_sub(learning_rate*grads)
# ```

# %% [markdown]
# For ‘ols_sgd’ and ‘mle_sgd’ we’ll create 2 private methods: `__sse_loss()` and `__mle_loss()` that compute and return the loss value for these 2 different techniques.
# For these 2 methods, we simply apply the formulas for f and h using TensorFlow’s math functions.
# ```python
# def __sse_loss(self, xb, yb):
#     yb = tf.math.maximum(self.EPS, tf.math.minimum(tf.cast(yb, tf.float32), 1-self.EPS))
#     ols_yb = -tf.math.log(tf.math.divide(1, yb) - 1)
#
#     diff = tf.linalg.matmul(xb, self.weights) - ols_yb
#     loss = tf.linalg.matmul(diff, diff, transpose_a=True)
#
#     return loss
#
# def __mle_loss(self, xb, yb):
#     xw = tf.linalg.matmul(xb, self.weights)
#     term1 = tf.linalg.matmul(tf.cast(1-yb, tf.float32), xw, transpose_a=True)
#     term2 = tf.linalg.matmul(
#         tf.ones_like(yb, tf.float32),
#         tf.math.log(1+tf.math.exp(-xw)),
#         transpose_a=True)
#     return term1+term2
# ```

# %% [markdown]
# So, when `fit()` is called with `method=‘ols_solve’` we call `__ols_solve()`, when `method=‘ols_sgd’` we call `__sgd()` with `loss_fn=self.__sse_loss`, and when `method=’mle_sgd’` we call `__sgd()` with `loss_fn=self.__mle_loss`.
# ```python
# def fit(self, x, y, method, learning_rate=0.001, iterations=500, batch_size=32):
#     x = tf.concat([x, tf.ones_like(y, dtype=tf.float32)], axis=1)
#     if method == "ols_solve":
#         self.__ols_solve(x, y)
#     elif method == "ols_sgd":
#         self.__sgd(x, y, self.__sse_loss, learning_rate, iterations, batch_size)
#     elif method == "mle_sgd":
#         self.__sgd(x, y, self.__mle_loss, learning_rate, iterations, batch_size)
#     else:
#         print(f'Unknown method: \'{method}\'')
#
#     return self
# ```

# %% [markdown]
# In `predict()` we first check if `fit()` was called previously by looking for the weights attribute (the fit method is the only method that creates it). Then we check if the shapes of the input matrix x and weights vector allow multiplication. Otherwise, return error messages. If everything is OK, we do the multiplication and pass the result through the logistic function.
# ```python
# def predict(self, x):
#     if not hasattr(self, 'weights'):
#         print('Cannot predict. You should call the .fit() method first.')
#         return
#
#     x = tf.concat([x, tf.ones((x.shape[0], 1), dtype=tf.float32)], axis=1)
#
#     if x.shape[1] != self.weights.shape[0]:
#         print(f'Shapes do not match. {x.shape[1]} != {self.weights.shape[0]}')
#         return
#
#     xw = tf.linalg.matmul(x, self.weights)
#     return tf.math.divide(1, 1+tf.math.exp(-xw))
# ```

# %% [markdown]
# In `accuracy()` we make predictions using the above method. Then check if the shape of the predictions matches that of the true labels, otherwise, we show an error message. After that we make sure that both predictions and the true labels have values of either 0 or 1 by a simple rule: if the value is >= 0.5 consider it a 1, otherwise a 0.
# To compute the accuracy, we check for equality between y and y_hat. This will return a vector of Boolean values. Then cast these Booleans to float (False becomes 0.0, and True becomes 1.0). Then, the accuracy is simply the mean of these values.
# ```python
# def accuracy(self, x, y):
#     y_hat = self.predict(x)
#
#     if y.shape != y_hat.shape:
#         print('Error! Predictions don\'t have the same shape as given y')
#         return
#
#     zeros, ones = tf.zeros_like(y), tf.ones_like(y)
#     y = tf.where(y >= 0.5, ones, zeros)
#     y_hat = tf.where(y_hat >= 0.5, ones, zeros)
#
#     return tf.math.reduce_mean(tf.cast(y == y_hat, tf.float32))
# ```

# %% [markdown]
# Here is the full code of the `LogisticRegression` class:

# %%
class LogisticRegression:
    EPS = 1e-5
    def __ols_solve(self, x, y):
        rows, cols = x.shape
        if rows >= cols == tf.linalg.matrix_rank(x):
            y = tf.math.maximum(self.EPS, tf.math.minimum(tf.cast(y, tf.float32), 1-self.EPS))
            ols_y = -tf.math.log(tf.math.divide(1, y) - 1)
            self.weights = tf.linalg.matmul(
                tf.linalg.matmul(
                    tf.linalg.inv(
                        tf.linalg.matmul(x, x, transpose_a=True)
                    ),
                    x, transpose_b=True),
                ols_y)
        else:
            print('Error! X has not full column rank.')
    
    def __sgd(self, x, y, loss_fn, learning_rate, iterations, batch_size):
        rows, cols = x.shape
        self.weights = tf.Variable(tf.random.normal(stddev=1.0/cols, shape=(cols, 1)))
        dataset = tf.data.Dataset.from_tensor_slices((x, y)).batch(batch_size)
        
        for i in range(iterations):
            dataset.shuffle(buffer_size=1024)
            for step, (xb, yb) in enumerate(dataset):
                with tf.GradientTape() as tape:
                    loss = loss_fn(xb, yb)
                grads = tape.gradient(loss, self.weights)
                self.weights.assign_sub(learning_rate*grads)
    
    def __sse_loss(self, xb, yb):
        yb = tf.math.maximum(self.EPS, tf.math.minimum(tf.cast(yb, tf.float32), 1-self.EPS))
        ols_yb = -tf.math.log(tf.math.divide(1, yb) - 1)
        
        diff = tf.linalg.matmul(xb, self.weights) - ols_yb
        loss = tf.linalg.matmul(diff, diff, transpose_a=True)
        
        return loss
    
    def __mle_loss(self, xb, yb):
        xw = tf.linalg.matmul(xb, self.weights)
        term1 = tf.linalg.matmul(tf.cast(1-yb, tf.float32), xw, transpose_a=True)
        term2 = tf.linalg.matmul(
            tf.ones_like(yb, tf.float32),
            tf.math.log(1+tf.math.exp(-xw)),
            transpose_a=True)
        return term1+term2
    
    def fit(self, x, y, method, learning_rate=0.001, iterations=500, batch_size=32):
        x = tf.concat([x, tf.ones_like(y, dtype=tf.float32)], axis=1)
        if method == "ols_solve":
            self.__ols_solve(x, y)
        elif method == "ols_sgd":
            self.__sgd(x, y, self.__sse_loss, learning_rate, iterations, batch_size)
        elif method == "mle_sgd":
            self.__sgd(x, y, self.__mle_loss, learning_rate, iterations, batch_size)
        else:
            print(f'Unknown method: \'{method}\'')
        
        return self
    
    def predict(self, x):
        if not hasattr(self, 'weights'):
            print('Cannot predict. You should call the .fit() method first.')
            return
        
        x = tf.concat([x, tf.ones((x.shape[0], 1), dtype=tf.float32)], axis=1)
        
        if x.shape[1] != self.weights.shape[0]:
            print(f'Shapes do not match. {x.shape[1]} != {self.weights.shape[0]}')
            return
        
        xw = tf.linalg.matmul(x, self.weights)
        return tf.math.divide(1, 1+tf.math.exp(-xw))
    
    def accuracy(self, x, y):
        y_hat = self.predict(x)
        
        if y.shape != y_hat.shape:
            print('Error! Predictions don\'t have the same shape as given y')
            return
        
        zeros, ones = tf.zeros_like(y), tf.ones_like(y)
        y = tf.where(y >= 0.5, ones, zeros)
        y_hat = tf.where(y_hat >= 0.5, ones, zeros)
        
        return tf.math.reduce_mean(tf.cast(y == y_hat, tf.float32))
    
    def evaluate(self, x, y):
        return

# %% [markdown]
# Now we want to see how our `LogisticRegression` class performs on this heart disease dataset.

# %%
def print_acc(model):
    print(f'Train accuracy = {model.accuracy(x_train, y_train)} ; '+
          f'Test accuracy = {model.accuracy(x_test, y_test)}')

# %% [markdown]
# ### Using 'ols_solve' method

# %%
lr_ols_solve = LogisticRegression().fit(x_train, y_train, 'ols_solve')
print_acc(lr_ols_solve)
# Out:
# Train accuracy = 0.8223140239715576 ; Test accuracy = 0.8852459192276001

# %% [markdown]
# ### Using 'ols_sgd' method

# %%
lr_ols_sgd = LogisticRegression().fit(x_train, y_train, 'ols_sgd')
print_acc(lr_ols_sgd)
# Out:
# Train accuracy = 0.8223140239715576 ; Test accuracy = 0.8852459192276001

# %% [markdown]
# ### Using 'mle_sgd' method

# %%
lr_mle_sgd = LogisticRegression().fit(x_train, y_train, 'mle_sgd')
print_acc(lr_mle_sgd)
# Out:
# Train accuracy = 0.8305785059928894 ; Test accuracy = 0.8360655903816223
